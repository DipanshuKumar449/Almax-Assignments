# %% [markdown]
# <a href="https://colab.research.google.com/github/DipanshuKumar449/Almax-Assignments/blob/main/Assignment_Week_2_Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MATH**

# %% [markdown]
# ## 1. Consider two random variables X and Y with joint PMF given in the following Table.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-28 at 16.20.53.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-28 at 16.20.53 (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-28 at 16.20.54.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. Let X and Y be jointly continuous random variables with joint PDF.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-28 at 16.25.45.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-28 at 16.25.45 (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-28 at 16.25.45 (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-28 at 16.28.22.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-28 at 16.25.46.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 3&4. Let X and Y be two jointly continuous random variables with joint PDF
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-28 at 16.31.41.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-28 at 16.31.42.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-28 at 16.31.42 (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-28 at 16.36.02.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-02-28 at 16.31.42 (3).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **MACHINE LEARNING**

# %% [markdown]
# ## 1. a. What is the Random Forest Algorithm?
#
# ## b. You’re asked to build a random forest model with 10000 trees. During its training, you got training error as 0.00. But, on testing the validation error was 34.23. What is going on? Haven’t you trained your model perfectly?

# %% [markdown]
# a) **Random Forest** is a popular machine learning algorithm that belongs to the supervised learning technique. It can be used for both Classification and Regression problems in ML. It is based on the concept of ensemble learning, which is a process of combining multiple classifiers to solve a complex problem and to improve the performance of the model.
#
# As the name suggests, "**Random Forest is a classifier that contains a number of decision trees on various subsets of the given dataset and takes the average to improve the predictive accuracy of that dataset**." Instead of relying on one decision tree, the random forest takes the prediction from each tree and based on the majority votes of predictions, and it predicts the final output.
#
# Random Forest works in two-phase first is to create the random forest by combining N decision tree, and second is to make predictions for each tree created in the first phase.
#
# The Working process can be explained in the below steps:
#
# Step-1: Select random K data points from the training set.
#
# Step-2: Build the decision trees associated with the selected data points (Subsets).
#
# Step-3: Choose the number N for decision trees that you want to build.
#
# Step-4: Repeat Step 1 & 2.
#
# Step-5: For new data points, find the predictions of each decision tree, and assign the new data points to the category that wins the majority votes.
#
# ![image.png](data:image/png;base64,...)
#
# **Advantages of Random Forest**:
# Random Forest is capable of performing both Classification and Regression tasks.
# It is capable of handling large datasets with high dimensionality and also enhances the accuracy of the model and prevents the overfitting issue
#
# b) This is a clear cut case of overfitting. Training error 0.00 means the model has mimiced the training data patterns to an extent, that they are not available in the unseen data. Hence, when this classifier was run on unseen sample, it couldn’t find those patterns and returned prediction with higher error. In random forest, it happens when we use larger number of trees than necessary. Hence, to avoid these situation, we should tune number of trees using cross validation.

# %% [markdown]
# ## 2. What are the differences between Adaboost and Gradient Boosting?

# %% [markdown]
# The differences are as follow:
# * **Adaboost** increases the performance of all the available machine learning algorithms and it is used to deal with weak learners. It gains accuracy just above the arbitrary chances of classifying the problem. The adaptable and most used algorithm in AdaBoost is decision trees with a single level.
# The **gradient boosting** depends on the intuition which is the next suitable possible model, when get combined with prior models that minimize the cumulative predicted errors. The crucial idea of gradient boosting is to fix the targeted outcomes for the next model to reduce the error.
# * The **Adaboosting** method minimizes the exponential loss function which changes the algorithm more profound to its outliers. In **gradient boosting**, the differentiable loss function makes more sensitive to outliers when compared to AdaBoost.
# * **Adaboost** is computed with a specific loss function and becomes more rigid when comes to few iterations. But in **gradient boosting**, it assists in finding the proper solution to additional iteration modeling problem as it is built with some generic features. From this, it is noted that gradient boosting is more flexible when compared to AdaBoost because of its fixed loss function values.
# * **Adaboost** is effective when it’s implied in week learners and when it is related to few classification errors it reduces the loss function. It was developed for problems that require binary classification and can be used to improve the efficiency of decision trees. In **gradient boosting**, it is used to crack the problems with differential loss functions. It can be implied in both regression problems and classification issues.
#
# A quick Summary:
#
# In Adaboost the shortcomings of previous models are identified by high-weight data points.In Gradient boosting the shortcomings of previous models are identified by the gradient.Each classifier in adaboost has different weights assigned to the final prediction based on its performance.	All classifiers in decision trees are weighed equally and their predictive capacity is restricted with learning rate to increase accuracy. Adaboost gives weights to both classifiers and observations thus capturing maximum variance within data.	Gradient boosting builds trees on previous classifier’s residuals thus capturing variance in data.

# %% [markdown]
# ## 3. What is Model Explainability and why is it required?

# %% [markdown]
# **Model explainability** refers to the ability to understand and interpret the decision-making process of a machine learning model. It involves the ability to trace back how the model arrived at a certain prediction or decision and to understand the factors that influenced the outcome.
#
# In very simple words: Explainability in machine learning is the process of explaining to a human why and how a machine learning model made a decision
#
# In recent years, there has been an increased focus on the **importance of model explainability**. This is because machine learning models are increasingly being used in critical applications such as healthcare, finance, and legal systems, where the consequences of errors or biases in the model can be significant. In these scenarios, it is important for the users of the model, including decision-makers and regulators, to understand how the model arrived at its predictions or decisions. This helps to build trust in the model and ensures that it is being used in a fair and ethical manner.
#
# Model explainability is also important for model development and improvement. By understanding the decision-making process of a model, data scientists can identify areas where the model may be biased or underperforming and make adjustments to improve its accuracy and fairness.

# %% [markdown]
# ## 4. What is the basic difference between ML Interpretability and ML Explainability?

# %% [markdown]
# Machine learning (ML) interpretability and explainability both refer to the ability to understand and interpret the results of a machine learning model. However, there is a subtle difference between the two concepts:
#
# * **ML Interpretabilit**y: It refers to the ability to understand how a model works and how it makes predictions. It focuses on the internal workings of the model, such as the weights and biases of the individual features used in the model. This understanding can help identify any biases or errors in the model, which can be important in high-stakes applications like healthcare or finance.
# * **ML Explainability**: It refers to the ability to explain the model's outputs or predictions to a human in a way that is understandable and intuitive. This involves identifying which factors or features of the input data are most important in influencing the model's decision, and how those factors are weighted or combined in the model. Explainability is important for building trust in the model and ensuring that its outputs are trustworthy and fair.
#
# In summary, interpretability focuses on understanding the inner workings of the model, while explainability focuses on communicating the model's behavior to humans in a transparent and intuitive way. Both interpretability and explainability are important for building trust in machine learning models and ensuring their effectiveness and fairness.
